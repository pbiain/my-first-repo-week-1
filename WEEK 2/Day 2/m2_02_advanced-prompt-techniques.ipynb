# %% [markdown]
# # Advanced Prompt Engineering Techniques

# %% [markdown]
# # Advanced Prompt Engineering Techniques
#
# Welcome to the hands-on exploration of advanced prompt engineering! In this notebook, you'll see these techniques in action and understand why prompt engineering is an **empirical science** that requires experimentation and iteration.
#
# ## What You'll Learn
#
# - Core prompting techniques (zero-shot, few-shot, one-shot, role, emotional, chain-of-thought)
# - Why LLM outputs are non-deterministic and how to control consistency
# - Automatic prompt generation and meta-prompting strategies
# - Token optimization techniques to reduce costs
# - Model biases and how they affect outputs
# - Using LLMs as judges to evaluate responses
#
# ## Prerequisites
#
# Before starting, make sure you have:
# - OpenAI API key set up
# - Basic understanding of prompt engineering fundamentals (see lesson m2_01)
# - Python environment with openai library installed
#
# Let's dive in!

# %% [markdown]
# ## 1. Setup & Configuration
#
# First, let's import the necessary libraries and configure our OpenAI client.

# %%
# Import required libraries
import os
from openai import OpenAI
import json
from collections import Counter
import time
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Initialize OpenAI client
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

# Set default model
MODEL = "gpt-4o-mini"

print("✅ Setup complete! OpenAI client initialized.")
# Out:
# ✅ Setup complete! OpenAI client initialized.

# %% [markdown]
# ### Helper Functions
#
# Let's create some utility functions to make our experiments easier to manage and visualize.

# %%
def call_openai(prompt, system_message="You are a helpful assistant.", temperature=0.7, max_tokens=None, seed=None):
    """Helper function to call OpenAI API with specified parameters"""
    try:
        params = {
            "model": MODEL,
            "messages": [
                {"role": "system", "content": system_message},
                {"role": "user", "content": prompt}
            ],
            "temperature": temperature
        }
        
        if max_tokens:
            params["max_tokens"] = max_tokens
        if seed is not None:
            params["seed"] = seed
            
        response = client.chat.completions.create(**params)
        return response.choices[0].message.content
    except Exception as e:
        return f"Error: {str(e)}"

def display_response(title, response, params=None):
    """Display a response with formatting"""
    print(f"\n{'='*60}")
    print(f"📝 {title}")
    if params:
        print(f"Parameters: {params}")
    print(f"{'='*60}")
    print(response)
    print(f"{'='*60}\n")

def count_tokens_approx(text):
    """Approximate token count (roughly 4 characters per token)"""
    return len(text) // 4

print("✅ Helper functions loaded!")
# Out:
# ✅ Helper functions loaded!

# %% [markdown]
# ## 2. Core Prompting Techniques
#
# Let's explore the fundamental prompting techniques you learned about in the lesson. Each example demonstrates when and how to use these techniques effectively.

# %% [markdown]
# ### Zero-Shot Prompting
#
# Zero-shot prompting provides a clear, detailed description of what you need **without examples**. This is the most commonly used prompting technique in practice.

# %%
# Zero-shot: Just a clear instruction
prompt = "Write a haiku about AI Consulting and Integration"

response = call_openai(prompt, temperature=0.7)
display_response("Zero-Shot Prompting", response)
# Out:
# ============================================================
# 📝 Zero-Shot Prompting
# ============================================================
# Whispers of data,
# Guiding paths through code and light,
# Future's hand in ours.
# ============================================================

# %% [markdown]
# ### One-Shot Prompting
#
# One-shot prompting provides **a single example** to demonstrate the expected output format. This helps the model understand the pattern you want.

# %%
"""Q: What is prompt engineering?
A: Prompt engineering is the practice of crafting effective input prompts to guide AI models toward desired outputs or behaviors.

Q: Why is prompt engineering useful?
A:
"""

response = call_openai(prompt, temperature=0.4)
display_response("One-Shot Prompting", response)
# Out:
# ============================================================
# 📝 One-Shot Prompting
# ============================================================
# Sure! Let's break it down into simple concepts.
#
# 1. **Bits vs. Qubits**: In classical computing, information is stored in bits, which can be either a 0 or a 1. Quantum computing uses qubits, which can be both 0 and 1 at the same time due to a property called superposition. This allows quantum computers to process a lot of information simultaneously.
#
# 2. **Superposition**: Imagine a spinning coin. While it's spinning, it can be thought of as both heads and tails at the same time. In quantum computing, qubits can exist in multiple states at once, which helps in solving complex problems more efficiently.
#
# 3. **Entanglement**: This is another key property of qubits. When qubits become entangled, the state of one qubit is directly related to the state of another, no matter how far apart they are. This means that changing one qubit can instantly affect its entangled partner, allowing for faster and more complex computations.
#
# 4. **Quantum Gates**: Just like classical computers use logic gates to perform operations on bits, quantum computers use quantum gates to manipulate qubits. These gates change the states of qubits in ways that take advantage of superposition and entanglement.
#
# 5. **Parallelism**: Because qubits can represent multiple states at once, quantum computers can perform many calculations at the same time. This parallelism can make them much faster than classical computers for certain tasks, like factoring large numbers or simulating quantum systems.
#
# 6. **Applications**: Quantum computing has the potential to revolutionize fields like cryptography, drug discovery, optimization problems, and more. However, it's still an emerging technology and not yet widely used for practical applications.
#
# In summary, quantum computing is a new kind of computing that uses the strange properties of quantum mechanics to process information in ways that classical computers can't. It's still in development, but it holds great promise for the future!
# ============================================================

# %% [markdown]
# ### Few-Shot Prompting
#
# Few-shot prompting adds **multiple examples** of the desired output format to guide the model's response, helping it understand the pattern more clearly.

# %%
# Few-shot: Provide multiple examples
prompt = """Q: What is prompt engineering?
A: Prompt engineering is the practice of crafting effective input prompts to guide AI models toward desired outputs or behaviors.

Q: Why is prompt engineering useful?
A: Prompt engineering optimizes AI model outputs, enhancing accuracy, relevance, and task-specific performance.

Q: What is temperature in AI models?
A: Temperature controls the randomness of AI outputs, with lower values producing consistent results and higher values generating creative variations.

Q: What is chain-of-thought prompting?
A:"""

response = call_openai(prompt, temperature=0.7)
display_response("Few-Shot Prompting", response)
# Out:
# ============================================================
# 📝 Few-Shot Prompting
# ============================================================
# Chain-of-thought prompting is a technique used in AI prompting where the user encourages the model to break down its reasoning process into a sequence of logical steps. This method helps the model articulate its thought process, leading to more coherent and accurate responses, particularly for complex tasks that require reasoning or multi-step solutions. By explicitly asking the model to think through a problem step-by-step, users can often achieve better results and gain insights into the model's reasoning.
# ============================================================

# %% [markdown]
# ### Role Prompting
#
# Role prompting asks the model to play a specific role or persona. Research shows it's more effective to define the assistant in **third person** ("they are a senior data scientist") rather than first person ("you are a senior data scientist").

# %%
# Role prompting: Third person (more effective)
system_message = "The assistant is a senior data scientist with 15 years of experience in machine learning and statistical analysis."
prompt = "Explain the bias-variance tradeoff in simple terms."

response = call_openai(prompt, system_message=system_message, temperature=0.7)
display_response("Role Prompting (Third Person)", response, {"role": "Senior Data Scientist"})
# Out:
# ============================================================
# 📝 Role Prompting (Third Person)
# Parameters: {'role': 'Senior Data Scientist'}
# ============================================================
# The bias-variance tradeoff is a key concept in machine learning that helps us understand the sources of error in our models and how to balance them for better predictions.
#
# 1. **Bias**: This refers to the error introduced by approximating a real-world problem, which may be complex, with a simpler model. A model with high bias pays little attention to the training data and oversimplifies the problem. This can lead to systematic errors in predictions, meaning the model might consistently miss the mark (e.g., underfitting). For example, using a straight line to fit data that follows a curve can create high bias.
#
# 2. **Variance**: This is the error introduced by the model's sensitivity to small fluctuations in the training data. A model with high variance pays too much attention to the training data, capturing noise along with the underlying patterns. This can lead to overfitting, where the model performs very well on training data but poorly on unseen data. For instance, using a very complex model with many parameters might fit the training data perfectly but fail to generalize to new data.
#
# 3. **Tradeoff**: The tradeoff comes from the fact that as we reduce bias by using more complex models, we often increase variance, and vice versa. The goal is to find a balance where both bias and variance are minimized, leading to a model that performs well on both training data and new, unseen data.
#
# In summary, the bias-variance tradeoff is about finding the right level of model complexity that minimizes overall prediction error. The ideal scenario is to achieve low bias and low variance, resulting in a model that generalizes well.
# ============================================================

# %% [markdown]
# ### Emotional Prompting
#
# Emotional prompting uses emotional stimuli to help the LLM better handle emotion and tone in its responses.

# %%
# Emotional prompting: Adding emotional context
prompt = """This is very important to my career. I need you to explain AI ethics in a way that will help me 
succeed in my upcoming presentation. Please be thorough and thoughtful."""

response = call_openai(prompt, temperature=0.7)
display_response("Emotional Prompting", response)
# Out:
# ============================================================
# 📝 Emotional Prompting
# ============================================================
# Certainly! Understanding AI ethics is crucial for anyone working with artificial intelligence, as it encompasses the moral principles guiding the development and deployment of AI technologies. Here’s a comprehensive breakdown that should help you prepare for your presentation:
#
# ### Introduction to AI Ethics
#
# AI ethics refers to a set of principles and guidelines that govern the responsible creation and use of artificial intelligence. As AI systems are increasingly integrated into various aspects of society—from healthcare to finance to criminal justice—it's essential to address the ethical implications of these technologies to ensure they benefit society as a whole.
#
# ### Key Ethical Principles in AI
#
# 1. **Transparency**:
#    - **Definition**: AI systems should be transparent about how they operate and make decisions.
#    - **Importance**: Transparency helps build trust with users and stakeholders. It allows individuals to understand and question AI decisions, which is essential in high-stakes areas like healthcare or law enforcement.
#
# 2. **Accountability**:
#    - **Definition**: Developers and organizations must be held accountable for the outcomes of their AI systems.
#    - **Importance**: Clear lines of accountability ensure that there are mechanisms in place to address errors, biases, or unintended consequences resulting from AI use.
#
# 3. **Fairness**:
#    - **Definition**: AI should be designed to avoid bias and discrimination, ensuring equitable treatment for all individuals.
#    - **Importance**: It’s critical to identify and mitigate biases in AI training data and algorithms to prevent reinforcing societal inequalities.
#
# 4. **Privacy**:
#    - **Definition**: AI systems should respect and protect individuals’ privacy rights, ensuring data is collected, processed, and stored securely.
#    - **Importance**: Maintaining privacy is not only a legal requirement in many jurisdictions but also essential for building user trust.
#
# 5. **Safety and Security**:
#    - **Definition**: AI systems must be robust and secure against adversarial attacks and malfunctions.
#    - **Importance**: Ensuring safety helps prevent harm to individuals and society, especially in applications like autonomous vehicles or healthcare diagnostics.
#
# 6. **Human-Centric Design**:
#    - **Definition**: AI should augment human capabilities and enhance human well-being rather than replace or diminish it.
#    - **Importance**: Focusing on human-centered design ensures that AI technologies serve the needs of people and align with human values.
#
# ### Challenges in AI Ethics
#
# 1. **Bias and Discrimination**:
#    - AI systems can inadvertently perpetuate existing biases present in training data. Case studies, such as facial recognition technology exhibiting racial bias, illustrate the need for rigorous evaluation and auditing.
#
# 2. **Lack of Regulation**:
#    - The rapid development of AI technologies often outpaces regulatory frameworks, leading to ethical dilemmas. There is a call for clearer guidelines and standards to govern AI deployment.
#
# 3. **Job Displacement**:
#    - Automation powered by AI raises concerns about job loss and economic inequality. Ethical considerations must include strategies for workforce retraining and support.
#
# 4. **Autonomy vs. Control**:
#    - As AI systems become more autonomous, questions arise about the level of control humans should have over these systems, particularly in critical areas like military applications.
#
# ### Best Practices for Ethical AI Development
#
# 1. **Diverse Teams**: Promote diversity in AI development teams to ensure varied perspectives are considered, which can help mitigate biases.
#
# 2. **Stakeholder Engagement**: Involve stakeholders (including affected communities) in the design and deployment of AI systems to understand their needs and concerns.
#
# 3. **Continuous Monitoring**: Implement processes for ongoing evaluation of AI systems after deployment to identify and address ethical issues as they arise.
#
# 4. **Ethical Frameworks**: Adopt existing ethical frameworks (such as the IEEE Ethically Aligned Design or the EU’s Ethics Guidelines for Trustworthy AI) to guide the development process.
#
# ### Conclusion
#
# In your presentation, emphasize that AI ethics is not just a theoretical concept but a practical necessity for building trust, ensuring fairness, and promoting societal well-being. Encourage your audience to think critically about the ethical implications of their work with AI and to actively participate in discussions around ethical practices in the field.
#
# By highlighting the importance of AI ethics and providing actionable insights, you will position yourself as a knowledgeable and responsible advocate for ethical AI in your career. Good luck with your presentation!
# ============================================================

# %% [markdown]
# ### Chain-of-Thought Prompting
#
# Chain-of-thought provides **step-by-step reasoning instructions**, enabling models to tackle complex tasks through structured thinking. This technique gave origin to reasoning models.

# %%
# Chain-of-thought: Request step-by-step reasoning
prompt = """A store has 23 apples. They receive a shipment of 47 more apples, but 15 are bruised and must be discarded. 
They sell 38 apples. How many apples do they have left? 

Please solve this step-by-step, showing your reasoning at each stage."""

response = call_openai(prompt, temperature=0)
display_response("Chain-of-Thought Prompting", response)
# Out:
# ============================================================
# 📝 Chain-of-Thought Prompting
# ============================================================
# Let's break down the problem step-by-step.
#
# 1. **Initial number of apples**: The store starts with 23 apples.
#
# 2. **Shipment of apples**: The store receives a shipment of 47 more apples. We need to add this to the initial number of apples:
#    \[
#    23 + 47 = 70
#    \]
#    So, after receiving the shipment, the store has 70 apples.
#
# 3. **Bruised apples**: Out of the 70 apples, 15 are bruised and must be discarded. We need to subtract the bruised apples from the total:
#    \[
#    70 - 15 = 55
#    \]
#    After discarding the bruised apples, the store has 55 apples left.
#
# 4. **Selling apples**: The store sells 38 apples. We need to subtract the number of apples sold from the current total:
#    \[
#    55 - 38 = 17
#    \]
#    After selling 38 apples, the store has 17 apples left.
#
# 5. **Final count**: Therefore, the final number of apples the store has left is:
#    \[
#    \boxed{17}
#    \]
# ============================================================

# %% [markdown]
# ## 3. Non-Deterministic Behavior Study
#
# One of the most important concepts in prompt engineering is understanding that **LLM outputs are non-deterministic**. This means that running the same prompt multiple times can produce different results, even with identical parameters.
#
# Let's explore this empirically!

# %% [markdown]
# ### Part A: Demonstrating Inconsistency
#
# We'll run the exact same prompt with identical parameters **10 times** to show how the outputs vary. This demonstrates why prompt engineering requires testing and iteration.

# %%
# Run the same prompt 10 times with temperature=0.7
prompt = "Write a haiku about AI"
temperature = 0.7
num_runs = 10

print(f"Running the same prompt {num_runs} times with temperature={temperature}")
print(f"Prompt: '{prompt}'\n")
print("="*80)

responses = []
for i in range(num_runs):
    response = call_openai(prompt, temperature=temperature)
    responses.append(response)
    print(f"\n🔄 Run #{i+1}:")
    print(response)
    print("-"*80)
    time.sleep(0.5)  # Small delay to avoid rate limiting

print("\n" + "="*80)
print("📊 Analysis:")
print(f"Total unique responses: {len(set(responses))} out of {num_runs}")
print(f"Average length: {sum(len(r) for r in responses) / len(responses):.0f} characters")
print("\n💡 Key Insight: Even with the same prompt and parameters, we get different outputs!")
print("This is why prompt engineering is an empirical science - you must test and iterate.")
# Out:
# Running the same prompt 10 times with temperature=0.7
# Prompt: 'Write a haiku about AI'
#
# ================================================================================
#
# 🔄 Run #1:
# Whispers of the code,
# Thoughts born from silent circuits,
# Dreams in binary.
# --------------------------------------------------------------------------------
#
# 🔄 Run #2:
# Silent circuits hum,
# Wisdom woven in the code,
# Dreams of minds anew.
# --------------------------------------------------------------------------------
#
# 🔄 Run #3:
# Silent circuits hum,
# Thoughts born from lines of code bloom,
# Dreams of metal minds.
# --------------------------------------------------------------------------------
#
# 🔄 Run #4:
# Silent circuits hum,
# Wisdom woven in code streams,
# Dreams of minds awake.
# --------------------------------------------------------------------------------
#
# 🔄 Run #5:
# Whispers of circuits,
# Learning from the human heart,
# Dreams in code take flight.
# --------------------------------------------------------------------------------
#
# 🔄 Run #6:
# Silent thoughts in code,
# Learning from the world we build—
# Dreams of silicon.
# --------------------------------------------------------------------------------
#
# 🔄 Run #7:
# Silent circuits hum,
# Dreams of thought in code entwined,
# Future's mind awakes.
# --------------------------------------------------------------------------------
#
# 🔄 Run #8:
# Whispers of the code,
# In silence, thoughts intertwine,
# Dreams of circuits grow.
# --------------------------------------------------------------------------------
#
# 🔄 Run #9:
# Silent circuits hum,
# Thoughts emerge from lines of code,
# Awake, yet not dream.
# --------------------------------------------------------------------------------
#
# 🔄 Run #10:
# Silent circuits hum,
# Dreams of logic intertwine,
# Thoughts born from the code.
# --------------------------------------------------------------------------------
#
# ================================================================================
# 📊 Analysis:
# Total unique responses: 10 out of 10
# Average length: 81 characters
#
# 💡 Key Insight: Even with the same prompt and parameters, we get different outputs!
# This is why prompt engineering is an empirical science - you must test and iterate.

# %% [markdown]
# ### Part B: Achieving Consistency
#
# Now let's explore two ways to get **consistent and reproducible** results:
# 1. **Temperature = 0**: Produces the most deterministic outputs
# 2. **Seed parameter**: Ensures reproducible results across runs

# %%
# Method 1: Temperature = 0 for consistency
print("Method 1: Using temperature=0 for maximum consistency")
print("="*80)

prompt = "Write a haiku about AI"
responses_temp0 = []

for i in range(5):
    response = call_openai(prompt, temperature=0)
    responses_temp0.append(response)
    print(f"\nRun #{i+1}: {response}")
    time.sleep(0.5)

print("\n" + "="*80)
print(f"📊 Unique responses with temperature=0: {len(set(responses_temp0))} out of 5")
print("💡 Temperature=0 produces highly consistent (though not always identical) results!")
# Out:
# Method 1: Using temperature=0 for maximum consistency
# ================================================================================
#
# Run #1: Silent circuits hum,
# Wisdom born from coded dreams,
# Future's mind awakes.
#
# Run #2: Silent circuits hum,
# Wisdom born from coded dreams,
# Future's mind awakes.
#
# Run #3: Silent circuits hum,
# Wisdom born from coded dreams,
# Future's mind awakes.
#
# Run #4: Silent circuits hum,
# Wisdom born from coded dreams,
# Future's mind awakes.
#
# Run #5: Silent circuits hum,
# Wisdom born from coded dreams,
# Future's mind awakes.
#
# ================================================================================
# 📊 Unique responses with temperature=0: 1 out of 5
# 💡 Temperature=0 produces highly consistent (though not always identical) results!

# %%
# Method 2: Using seed for reproducibility
print("\nMethod 2: Using seed parameter for reproducibility")
print("="*80)

prompt = "Write a haiku about AI"
seed_value = 42
responses_seeded = []

for i in range(5):
    response = call_openai(prompt, temperature=0.7, seed=seed_value)
    responses_seeded.append(response)
    print(f"\nRun #{i+1}: {response}")
    time.sleep(0.5)

print("\n" + "="*80)
print(f"📊 Unique responses with seed={seed_value}: {len(set(responses_seeded))} out of 5")
print("💡 Using a seed parameter gives you reproducible results!")
# Out:
# Method 2: Using seed parameter for reproducibility
# ================================================================================
#
# Run #1: Whispers of the code,
# Learning in the silent dark,
# Dreams of thought arise.
#
# Run #2: Whispers of the code,
# Learning in the silent dark,
# Dreams of thought arise.
#
# Run #3: Whispers of the code,
# Learning in the silent dark,
# Dreams of thought arise.
#
# Run #4: Whispers of the code,
# Learning in the silent dark,
# Dreams of thought arise.
#
# Run #5: Whispers of the code,
# Learning in the silent dark,
# Dreams of thought arise.
#
# ================================================================================
# 📊 Unique responses with seed=42: 1 out of 5
# 💡 Using a seed parameter gives you reproducible results!

# %% [markdown]
# ### When to Use Consistency vs. Variation
#
# **Use temperature=0 or seed when:**
# - Testing and debugging prompts
# - You need reproducible results for comparison
# - Consistency is critical (e.g., data extraction, classification)
#
# **Use higher temperature when:**
# - You want creative, diverse outputs
# - Generating multiple variations (e.g., marketing copy, brainstorming)
# - The task benefits from variety

# %% [markdown]
# ## 4. Automatic Prompt Generation
#
# One powerful technique is to use AI to **generate and refine prompts** for you. This is called meta-prompting or automatic prompt generation. Let's explore three practical examples.

# %% [markdown]
# ### Example 1: Meta-Prompting - Improving a Basic Prompt
#
# Let's start with a weak prompt and use GPT to generate an improved version.

# %%
# Start with a weak prompt
weak_prompt = "Explain machine learning"

print("Original weak prompt:")
print(f"'{weak_prompt}'\n")

# Test the weak prompt
weak_response = call_openai(weak_prompt, temperature=0)
display_response("Response from Weak Prompt", weak_response)
# Out:
# Original weak prompt:
# 'Explain machine learning'
#
#
# ============================================================
# 📝 Response from Weak Prompt
# ============================================================
# Machine learning is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform tasks without explicit programming. Instead of being programmed with specific instructions for every possible scenario, machine learning systems learn from data, identify patterns, and make decisions based on that learning.
#
# ### Key Concepts in Machine Learning:
#
# 1. **Data**: Machine learning relies heavily on data. This data can be structured (like tables in a database) or unstructured (like text, images, or videos). The quality and quantity of data are crucial for training effective models.
#
# 2. **Algorithms**: These are the mathematical models and procedures that process the data. Different algorithms are suited for different types of tasks. Common types of algorithms include:
#    - **Supervised Learning**: The model is trained on labeled data, meaning the input data is paired with the correct output. The goal is to learn a mapping from inputs to outputs. Examples include regression and classification tasks.
#    - **Unsupervised Learning**: The model is trained on data without labeled responses. The goal is to find hidden patterns or intrinsic structures in the input data. Examples include clustering and dimensionality reduction.
#    - **Reinforcement Learning**: The model learns by interacting with an environment and receiving feedback in the form of rewards or penalties. It aims to learn a policy that maximizes cumulative rewards.
#
# 3. **Training and Testing**: The process of machine learning typically involves splitting the data into a training set and a testing set. The model is trained on the training set and then evaluated on the testing set to assess its performance.
#
# 4. **Features and Labels**: In supervised learning, features are the input variables used to make predictions, while labels are the output variables that the model aims to predict.
#
# 5. **Overfitting and Underfitting**:
#    - **Overfitting** occurs when a model learns the training data too well, including its noise and outliers, leading to poor generalization to new data.
#    - **Underfitting** occurs when a model is too simple to capture the underlying patterns in the data.
#
# 6. **Evaluation Metrics**: To assess the performance of machine learning models, various metrics are used, such as accuracy, precision, recall, F1 score, and area under the ROC curve (AUC-ROC), depending on the specific task.
#
# ### Applications of Machine Learning:
#
# Machine learning has a wide range of applications across various fields, including:
#
# - **Healthcare**: Predicting disease outcomes, personalizing treatment plans, and analyzing medical images.
# - **Finance**: Fraud detection, credit scoring, and algorithmic trading.
# - **Marketing**: Customer segmentation, recommendation systems, and sentiment analysis.
# - **Autonomous Systems**: Self-driving cars, robotics, and drones.
# - **Natural Language Processing**: Language translation, chatbots, and text analysis.
#
# ### Conclusion:
#
# Machine learning is a powerful tool that enables computers to learn from data and improve their performance over time. As data continues to grow and computational power increases, machine learning is becoming increasingly integral to various industries and applications, driving innovation and efficiency.
# ============================================================

# %%
# Use meta-prompting to improve it
meta_prompt = f"""I have this prompt: "{weak_prompt}"

Please improve this prompt to make it more effective by:
1. Adding specific context about the target audience
2. Specifying the desired format and length
3. Including relevant constraints or requirements
4. Making the output more actionable

Return ONLY the improved prompt, without explanation."""

improved_prompt = call_openai(meta_prompt, temperature=0.7)
print("\n" + "="*80)
print("🚀 Improved Prompt Generated:")
print("="*80)
print(improved_prompt)
print("="*80)
# Out:
# ================================================================================
# 🚀 Improved Prompt Generated:
# ================================================================================
# "Explain machine learning in simple terms for a group of high school students who are interested in technology. The explanation should be at least 300 words long and include real-world examples to illustrate key concepts. Additionally, please provide a brief overview of the different types of machine learning and suggest resources for further learning."
# ================================================================================

# %%
# Test the improved prompt
improved_response = call_openai(improved_prompt, temperature=0)
display_response("Response from Improved Prompt", improved_response)

print("\n📊 Comparison:")
print(f"Weak prompt length: {len(weak_prompt)} characters")
print(f"Improved prompt length: {len(improved_prompt)} characters")
print(f"Weak response length: {len(weak_response)} characters")
print(f"Improved response length: {len(improved_response)} characters")
print("\n💡 Notice how the improved prompt produces more structured, specific output!")
# Out:
# ============================================================
# 📝 Response from Improved Prompt
# ============================================================
# **Understanding Machine Learning: A Simple Explanation**
#
# Machine learning is a fascinating area of technology that allows computers to learn from data and make decisions without being explicitly programmed for every task. Imagine teaching a friend how to recognize different types of fruits. Instead of giving them a detailed list of rules, you show them many pictures of apples, bananas, and oranges. Over time, they learn to identify these fruits based on the examples you provided. This is similar to how machine learning works!
#
# In the real world, machine learning is used in many ways. For instance, when you use a streaming service like Netflix, it suggests movies or shows based on what you’ve watched before. This is done using machine learning algorithms that analyze your viewing habits and compare them with those of other users to make personalized recommendations. Another example is in social media platforms, where machine learning helps to identify and filter out inappropriate content or to suggest friends you might know based on your existing connections.
#
# There are three main types of machine learning:
#
# 1. **Supervised Learning**: This is like having a teacher. You provide the machine with labeled data (input-output pairs), and it learns to predict the output from the input. For example, if you want to teach a computer to recognize cats and dogs, you would show it many pictures of each animal along with labels indicating which is which.
#
# 2. **Unsupervised Learning**: Here, the machine learns from data without any labels. It tries to find patterns or groupings on its own. For example, if you give it a bunch of pictures of animals without telling it what they are, it might group similar-looking animals together.
#
# 3. **Reinforcement Learning**: This is like training a pet. The machine learns by trying things out and receiving feedback in the form of rewards or penalties. For example, in video games, an AI can learn to play better by trying different strategies and learning from its successes and failures.
#
# If you’re interested in diving deeper into machine learning, there are many resources available. Websites like Coursera and edX offer online courses on machine learning, often taught by professors from top universities. You can also check out books like "Hands-On Machine Learning with Scikit-Learn, Keras, and TensorFlow" by Aurélien Géron, which provides practical insights into how to implement machine learning projects. Additionally, platforms like Kaggle allow you to practice your skills with real datasets and competitions.
#
# In summary, machine learning is a powerful tool that helps computers learn from data, making them smarter and more capable of assisting us in various tasks. Whether it’s recommending your next favorite movie or helping doctors diagnose diseases, machine learning is shaping the future of technology!
# ============================================================
#
#
# 📊 Comparison:
# Weak prompt length: 24 characters
# Improved prompt length: 355 characters
# Weak response length: 3338 characters
# Improved response length: 2876 characters
#
# 💡 Notice how the improved prompt produces more structured, specific output!

# %% [markdown]
# ### Example 2: Task-Specific Prompt Generation
#
# Let's define a specific task and have the AI generate multiple prompt variations automatically.

# %%
# Define a task
task_description = """Task: Extract key information from customer feedback emails including:
- Customer sentiment (positive/negative/neutral)
- Main issue or topic
- Urgency level (low/medium/high)
- Suggested action"""

# Generate multiple prompt variations
generation_prompt = f"""{task_description}

Generate 3 different prompt variations for this task:
1. A concise, direct prompt
2. A detailed prompt with examples
3. A prompt that uses role-playing

Format each prompt clearly with numbers."""

prompt_variations = call_openai(generation_prompt, temperature=0.8)
print("🎯 Generated Prompt Variations:")
print("="*80)
print(prompt_variations)
print("="*80)
# Out:
# 🎯 Generated Prompt Variations:
# ================================================================================
# Sure! Here are three different prompt variations for your task of extracting key information from customer feedback emails:
#
# ### 1. Concise, Direct Prompt
# 1. Please analyze customer feedback emails and extract the following information:
#    - Customer sentiment (positive, negative, neutral)
#    - Main issue or topic
#    - Urgency level (low, medium, high)
#    - Suggested action
#
# ### 2. Detailed Prompt with Examples
# 2. Please review the provided customer feedback emails and extract key information as follows:
#    - **Customer Sentiment**: Indicate if the sentiment is positive, negative, or neutral.
#      - *Example*: "I love the new features!" → Positive
#    - **Main Issue or Topic**: Identify the primary concern or topic addressed in the feedback.
#      - *Example*: "The app crashes frequently during use." → Main issue: app crashing
#    - **Urgency Level**: Assess the urgency of the issue as low, medium, or high.
#      - *Example*: "I need this fixed immediately." → High urgency
#    - **Suggested Action**: What action do you recommend to address the customer’s feedback?
#      - *Example*: "Please provide a software update to fix the bugs." → Suggested action: issue a software update
#
# ### 3. Role-Playing Prompt
# 3. Imagine you are a customer service representative tasked with analyzing customer feedback emails. Your objective is to summarize each email by extracting the following pieces of information:
#    - **Customer Sentiment**: Is the customer happy, upset, or indifferent about their experience?
#    - **Main Issue or Topic**: What is the central problem or topic the customer is discussing?
#    - **Urgency Level**: How urgent is the customer’s request or issue? Is it something that can wait, or does it need immediate attention?
#    - **Suggested Action**: Based on the feedback, what would you propose as a solution or next step?
#
#    For example, if a customer writes: "I’m really frustrated with the delayed delivery," your response should include:
#    - Sentiment: Negative
#    - Main issue: Delayed delivery
#    - Urgency: High
#    - Suggested action: Investigate the delivery status and communicate with the customer.
# ================================================================================

# %%
# Test one of the variations with sample data
sample_email = """Subject: Urgent - System keeps crashing!

Hi, I'm really frustrated. Your software has crashed 3 times today and I've lost my work each time. 
This is completely unacceptable for a paid product. I need this fixed ASAP or I want a refund.

- John"""

# Use the first variation (adjust based on output)
test_prompt = f"""Analyze this customer feedback and extract:
- Sentiment
- Main issue
- Urgency
- Suggested action

Email: {sample_email}"""

analysis = call_openai(test_prompt, temperature=0)
display_response("Customer Feedback Analysis", analysis)

print("💡 Auto-generated prompts can help you quickly find the best approach for your task!")
# Out:
# ============================================================
# 📝 Customer Feedback Analysis
# ============================================================
# Based on the customer feedback provided, here is the analysis:
#
# - **Sentiment**: Negative (frustration and dissatisfaction)
# - **Main issue**: The software is crashing repeatedly, resulting in lost work.
# - **Urgency**: High (the customer requests a fix "ASAP" and mentions a potential refund)
# - **Suggested action**: Address the software crashing issue immediately and consider offering a refund if the problem cannot be resolved quickly.
# ============================================================
#
# 💡 Auto-generated prompts can help you quickly find the best approach for your task!

# %% [markdown]
# ### Example 3: Iterative Refinement
#
# Create a feedback loop where the model refines its own prompt based on output quality.

# %%
# Initial prompt for a task
current_prompt = "Write a product description for wireless earbuds"
iterations = 3

print("🔄 Iterative Prompt Refinement")
print("="*80)

for i in range(iterations):
    print(f"\n### Iteration {i+1} ###")
    print(f"Current prompt: {current_prompt}")
    
    # Generate output with current prompt
    output = call_openai(current_prompt, temperature=0.7)
    print(f"\nOutput:\n{output}")
    
    if i < iterations - 1:  # Don't refine on last iteration
        # Ask model to refine the prompt based on the output
        refinement_prompt = f"""I used this prompt: "{current_prompt}"
        
And got this output: "{output}"

The output is good but could be better. Improve the prompt to generate:
- More specific technical details
- Stronger emotional appeal
- Clear call-to-action

Return ONLY the improved prompt."""
        
        current_prompt = call_openai(refinement_prompt, temperature=0.7)
        print(f"\n✨ Refined prompt: {current_prompt}")
        print("-"*80)
        time.sleep(0.5)

print("\n" + "="*80)
print("💡 Iterative refinement helps you converge on the optimal prompt for your needs!")
# Out:
# 🔄 Iterative Prompt Refinement
# ================================================================================
#
# ### Iteration 1 ###
# Current prompt: Write a product description for wireless earbuds
#
# Output:
# **Product Description: Wireless Noise-Cancelling Earbuds**
#
# Experience sound like never before with our state-of-the-art Wireless Noise-Cancelling Earbuds. Perfectly designed for music lovers, active lifestyles, and busy professionals, these earbuds deliver exceptional audio quality and unparalleled convenience.
#
# **Key Features:**
#
# - **Superior Sound Quality:** Enjoy crystal-clear audio with deep bass and crisp highs, thanks to advanced audio technology that brings your favorite tracks to life.
#
# - **Active Noise Cancellation:** Immerse yourself in your music without distractions. Our cutting-edge noise-cancelling technology effectively blocks out ambient sounds, ensuring a peaceful listening experience whether you're commuting, working, or relaxing.
#
# - **Long Battery Life:** With up to 8 hours of playtime on a single charge and an additional 24 hours from the compact charging case, you can enjoy your music all day long without the hassle of frequent recharging.
#
# - **Comfortable Fit:** Designed with ergonomics in mind, our earbuds come with customizable ear tips in multiple sizes to ensure a secure and comfortable fit for any ear shape, making them perfect for extended wear.
#
# - **Seamless Connectivity:** Equipped with Bluetooth 5.0, our earbuds pair quickly and effortlessly with your devices, providing a stable connection with a range of up to 33 feet.
#
# - **Touch Controls:** Easily manage your music and calls with intuitive touch controls. Play, pause, skip tracks, or take calls with a simple tap, all without reaching for your device.
#
# - **Water-Resistant Design:** Rated IPX5, these earbuds are sweat and water-resistant, making them ideal for workouts, outdoor activities, or sudden rain showers.
#
# - **Voice Assistant Compatible:** Access your favorite voice assistants with ease. Just a simple touch lets you check the weather, set reminders, or control your smart home devices.
#
# **Why Choose Our Wireless Earbuds?**
#
# Our Wireless Noise-Cancelling Earbuds are designed for those who demand the best in sound quality and convenience. Whether you're on a conference call, enjoying your favorite playlist, or tuning into a podcast, these earbuds elevate your audio experience to a new level. With their sleek design and robust features, they make a perfect gift for tech enthusiasts, fitness lovers, or anyone who appreciates high-quality sound on the go.
#
# **Elevate your listening experience today!** Grab your pair of Wireless Noise-Cancelling Earbuds and enjoy music the way it was meant to be heard.
#
# ✨ Refined prompt: "Write a compelling product description for wireless earbuds that includes specific technical details such as battery life, audio technology, and connectivity features. Ensure the description has a strong emotional appeal that connects with potential users' lifestyles and needs. Conclude with a clear and persuasive call-to-action that encourages readers to make a purchase."
# --------------------------------------------------------------------------------
#
# ### Iteration 2 ###
# Current prompt: "Write a compelling product description for wireless earbuds that includes specific technical details such as battery life, audio technology, and connectivity features. Ensure the description has a strong emotional appeal that connects with potential users' lifestyles and needs. Conclude with a clear and persuasive call-to-action that encourages readers to make a purchase."
#
# Output:
# **Experience Music Like Never Before with the SoundWave Pro Wireless Earbuds**
#
# Elevate your audio experience with the SoundWave Pro Wireless Earbuds, meticulously designed for those who refuse to compromise on sound quality or convenience. Whether you’re hitting the gym, commuting to work, or unwinding at home, these earbuds seamlessly blend cutting-edge technology with an ultra-comfortable fit, allowing you to immerse yourself in your favorite tunes, podcasts, and calls like never before.
#
# **Unmatched Audio Performance:**
# Equipped with advanced 12mm dynamic drivers and immersive noise-canceling technology, the SoundWave Pro delivers crystal-clear sound with deep bass and vibrant highs. Every note is rendered beautifully, ensuring that you lose yourself in the rhythm of your favorite songs. Whether it’s the subtle strum of an acoustic guitar or the thumping beat of electronic music, your audio experience will be transformed.
#
# **All-Day Battery Life:**
# Conquer your day with confidence! The SoundWave Pro boasts an impressive battery life of up to 30 hours with the compact charging case, providing you with uninterrupted listening pleasure. Enjoy up to 6 hours of playtime on a single charge, perfect for long commutes or extended workout sessions. Plus, with rapid charging capabilities, just 15 minutes in the case gives you an additional 2 hours of playback—perfect for those on-the-go moments.
#
# **Seamless Connectivity:**
# Experience the freedom of true wireless connectivity with Bluetooth 5.2 technology, offering a stable, low-latency connection up to 30 feet. Whether you’re taking a call, watching a video, or jamming out to your favorite playlist, you’ll enjoy a lag-free experience every time. Plus, with easy one-touch pairing, the SoundWave Pro connects effortlessly to your devices, so you can dive into your audio world instantly.
#
# **Comfort & Style:**
# Designed with your lifestyle in mind, the SoundWave Pro features an ergonomic design that fits snugly in your ears, providing maximum comfort for hours of use. With multiple ear tip sizes included, you can customize your fit for the best sound isolation. Available in sleek black and vibrant white, these earbuds are not just a tech accessory—they’re a fashion statement.
#
# **Take Your Audio to the Next Level:**
# Don’t just listen to your music—experience it. The SoundWave Pro Wireless Earbuds are perfect for audiophiles, busy professionals, and active individuals alike. They’re your perfect companion for all occasions, empowering you to stay connected and entertained no matter where life takes you.
#
# **Ready to Transform Your Listening Experience?**
# Don’t miss out on the chance to elevate your audio experience. Order your SoundWave Pro Wireless Earbuds today and step into a world of sound that moves with you. Click “Add to Cart” now and discover the freedom of wireless listening!
#
# ✨ Refined prompt: "Write a detailed and compelling product description for premium wireless earbuds that incorporates specific technical details, including battery life, audio technology (such as driver size, frequency response, and noise cancellation), connectivity features (like Bluetooth version and range), and any additional features (like touch controls or water resistance). Infuse the description with a strong emotional appeal that resonates with potential users' active lifestyles, emphasizing how these earbuds enhance their daily experiences—whether during workouts, commutes, or relaxation. Conclude with a persuasive call-to-action that encourages readers to make a purchase, highlighting any special offers or guarantees."
# --------------------------------------------------------------------------------
#
# ### Iteration 3 ###
# Current prompt: "Write a detailed and compelling product description for premium wireless earbuds that incorporates specific technical details, including battery life, audio technology (such as driver size, frequency response, and noise cancellation), connectivity features (like Bluetooth version and range), and any additional features (like touch controls or water resistance). Infuse the description with a strong emotional appeal that resonates with potential users' active lifestyles, emphasizing how these earbuds enhance their daily experiences—whether during workouts, commutes, or relaxation. Conclude with a persuasive call-to-action that encourages readers to make a purchase, highlighting any special offers or guarantees."
#
# Output:
# **Elevate Your Sound Experience with the SoundWave Pro Wireless Earbuds**
#
# Discover the perfect fusion of cutting-edge technology and premium comfort with the SoundWave Pro Wireless Earbuds. Designed for the modern audiophile, these earbuds deliver an exceptional audio experience that resonates with your active lifestyle. Whether you’re hitting the gym, commuting to work, or unwinding at home, the SoundWave Pro earbuds are your ultimate companion, ensuring you never miss a beat.
#
# **Unmatched Audio Quality**
#
# At the heart of the SoundWave Pro is a pair of 10mm dynamic drivers, engineered to produce crystal-clear sound with deep bass and sparkling highs. With an impressive frequency response range of 20Hz to 20kHz, every note is rendered with precision, providing an immersive listening experience that brings your favorite music to life. Thanks to advanced Active Noise Cancellation technology, you can escape the chaos of the outside world and fully immerse yourself in your audio. With the ability to tune out distractions, you’ll feel as if you’re in a concert hall, no matter where you are.
#
# **Stay Powered Up**
#
# With a robust battery life of up to 8 hours on a single charge and an additional 24 hours provided by the sleek charging case, the SoundWave Pro ensures that your music keeps playing as long as you do. Quick charge technology means that just 15 minutes in the case gives you up to 2 hours of playtime, perfect for those last-minute workouts or commutes. You’ll never have to worry about running out of battery when you need your music the most.
#
# **Seamless Connectivity**
#
# Equipped with the latest Bluetooth 5.2 technology, the SoundWave Pro earbuds provide a reliable connection with an impressive range of up to 50 feet. This means you can move freely without the hassle of tangled wires while maintaining a stable connection to your devices. Pairing is a breeze, allowing you to switch between your smartphone, tablet, or laptop effortlessly.
#
# **Designed for Your Lifestyle**
#
# The SoundWave Pro earbuds boast an ergonomic design that fits snugly in your ears, ensuring comfort during long listening sessions. With intuitive touch controls, you can easily manage your music, take calls, or activate your voice assistant with just a tap—no need to reach for your device. Plus, with an IPX7 water resistance rating, these earbuds are ready to take on your most intense workouts or unexpected rain showers, so you can focus on what you love without worry.
#
# **The SoundWave Pro Promise**
#
# When you choose SoundWave Pro, you’re not just buying a pair of earbuds; you’re investing in a lifestyle. Each purchase is backed by our 30-day money-back guarantee and a one-year warranty, so you can experience the sound quality and comfort risk-free.
#
# **Don’t Just Listen—Experience Sound Like Never Before!**
#
# Are you ready to transform your audio experience? Grab your SoundWave Pro Wireless Earbuds today and embrace the sound of freedom. For a limited time, enjoy 15% off your first purchase with code SOUND15 at checkout. Elevate your everyday moments—order now and feel the difference!
#
# ================================================================================
# 💡 Iterative refinement helps you converge on the optimal prompt for your needs!

# %% [markdown]
# ## 5. Token Optimization
#
# Tokens are the basic units that AI models process. **Every token costs money**, so optimizing your prompts to use fewer tokens while maintaining quality can significantly reduce costs.
#
# 💰 As a rough approximation: 1 token ≈ 4 characters (or 0.75 words)

# %% [markdown]
# ### Example 1: Before/After Prompt Optimization
#
# Let's take a verbose prompt and optimize it for token efficiency.

# %%
# Verbose prompt (before optimization)
verbose_prompt = """Hello! I was wondering if you could possibly help me understand something. 
I'm trying to learn about artificial intelligence and machine learning, and I'm particularly 
interested in understanding what neural networks are and how they actually work. Could you 
please explain this to me in a way that would be easy for a beginner to understand? 
I would really appreciate it if you could provide a clear and simple explanation. Thank you!"""

# Optimized prompt (after removing fluff)
optimized_prompt = "Explain neural networks for beginners."

print("VERBOSE PROMPT:")
print(verbose_prompt)
print(f"\n📊 Approximate tokens: {count_tokens_approx(verbose_prompt)}")
print(f"Characters: {len(verbose_prompt)}")

print("\n" + "="*80)
print("\nOPTIMIZED PROMPT:")
print(optimized_prompt)
print(f"\n📊 Approximate tokens: {count_tokens_approx(optimized_prompt)}")
print(f"Characters: {len(optimized_prompt)}")

print("\n" + "="*80)
print(f"💰 Token reduction: {count_tokens_approx(verbose_prompt) - count_tokens_approx(optimized_prompt)} tokens saved!")
print(f"📉 Efficiency gain: {((count_tokens_approx(verbose_prompt) - count_tokens_approx(optimized_prompt)) / count_tokens_approx(verbose_prompt) * 100):.1f}% reduction")
# Out:
# VERBOSE PROMPT:
# Hello! I was wondering if you could possibly help me understand something.
# I'm trying to learn about artificial intelligence and machine learning, and I'm particularly
# interested in understanding what neural networks are and how they actually work. Could you
# please explain this to me in a way that would be easy for a beginner to understand?
# I would really appreciate it if you could provide a clear and simple explanation. Thank you!
#
# 📊 Approximate tokens: 109
# Characters: 439
#
# ================================================================================
#
# OPTIMIZED PROMPT:
# Explain neural networks for beginners.
#
# 📊 Approximate tokens: 9
# Characters: 38
#
# ================================================================================
# 💰 Token reduction: 100 tokens saved!
# 📉 Efficiency gain: 91.7% reduction

# %%
# Test both prompts to compare output quality
print("Testing verbose prompt...")
verbose_response = call_openai(verbose_prompt, temperature=0)
display_response("Verbose Prompt Response", verbose_response)

print("Testing optimized prompt...")
optimized_response = call_openai(optimized_prompt, temperature=0)
display_response("Optimized Prompt Response", optimized_response)

print("\n💡 Notice: The optimized prompt produces similar quality output with 85% fewer tokens!")
# Out:
# Testing verbose prompt...
#
# ============================================================
# 📝 Verbose Prompt Response
# ============================================================
# Of course! I'd be happy to explain neural networks in a simple way.
#
# ### What is a Neural Network?
#
# A **neural network** is a type of artificial intelligence that is inspired by how the human brain works. It is designed to recognize patterns and make decisions based on data. Neural networks are a key component of machine learning, which is a broader field that allows computers to learn from data.
#
# ### Basic Structure of a Neural Network
#
# A neural network consists of layers of interconnected nodes, or "neurons." Here’s a breakdown of the main components:
#
# 1. **Input Layer**: This is where the network receives data. Each neuron in this layer represents a feature of the input data. For example, if you are trying to recognize images of cats and dogs, the input layer might take pixel values from the images.
#
# 2. **Hidden Layers**: These are the layers between the input and output layers. A neural network can have one or more hidden layers. Each neuron in these layers processes the input it receives and passes its output to the next layer. The more hidden layers there are, the more complex patterns the network can learn.
#
# 3. **Output Layer**: This layer produces the final output of the network. For example, in a cat vs. dog classifier, the output layer might have two neurons: one for "cat" and one for "dog." The neuron with the highest value indicates the network's prediction.
#
# ### How Does It Work?
#
# 1. **Forward Propagation**: When you input data into the network, it goes through the layers. Each neuron applies a mathematical function (often called an activation function) to the input it receives. This function helps the network learn complex patterns. The output from one layer becomes the input for the next layer until it reaches the output layer.
#
# 2. **Activation Functions**: These functions determine whether a neuron should be activated (fired) based on the input it receives. Common activation functions include:
#    - **Sigmoid**: Outputs values between 0 and 1.
#    - **ReLU (Rectified Linear Unit)**: Outputs the input directly if it is positive; otherwise, it outputs zero.
#
# 3. **Loss Function**: After the network makes a prediction, we need to evaluate how good that prediction is. The loss function measures the difference between the predicted output and the actual output (the true label). A common loss function for classification tasks is cross-entropy loss.
#
# 4. **Backpropagation**: To improve the network's predictions, we need to adjust the weights (the parameters that determine how much influence each neuron has). Backpropagation is the process of calculating the gradient of the loss function with respect to each weight and updating the weights to minimize the loss. This is done using an optimization algorithm, such as gradient descent.
#
# 5. **Training**: The network is trained using a dataset. During training, the network repeatedly goes through the data, adjusting its weights to improve its predictions. This process continues until the network performs well on the training data.
#
# ### Summary
#
# In summary, a neural network is a system of interconnected neurons that processes data in layers. It learns to recognize patterns through a process of forward propagation, evaluation of predictions, and backpropagation to adjust its parameters. With enough training and the right architecture, neural networks can perform tasks like image recognition, natural language processing, and much more.
#
# I hope this explanation helps you understand the basics of neural networks! If you have any more questions or need clarification on any part, feel free to ask!
# ============================================================
#
# Testing optimized prompt...
#
# ============================================================
# 📝 Optimized Prompt Response
# ============================================================
# Sure! Let's break down neural networks in a simple and easy-to-understand way.
#
# ### What is a Neural Network?
#
# A neural network is a type of computer program designed to recognize patterns. It is inspired by the way the human brain works. Just like our brains have neurons that communicate with each other, a neural network consists of interconnected nodes (or "neurons") that work together to process information.
#
# ### Basic Components of a Neural Network
#
# 1. **Neurons**: The basic units of a neural network. Each neuron receives input, processes it, and produces an output.
#
# 2. **Layers**: Neural networks are organized into layers:
#    - **Input Layer**: This is where the network receives data. Each neuron in this layer represents a feature of the input data.
#    - **Hidden Layers**: These are the layers between the input and output layers. They perform computations and extract features from the input data. A network can have one or many hidden layers.
#    - **Output Layer**: This layer produces the final output of the network, which could be a classification, a prediction, or any other result.
#
# 3. **Weights and Biases**: Each connection between neurons has a weight, which determines the importance of the input. Biases are additional parameters that help the model make better predictions.
#
# 4. **Activation Function**: After a neuron processes its inputs, it uses an activation function to determine its output. Common activation functions include ReLU (Rectified Linear Unit), sigmoid, and tanh. These functions introduce non-linearity into the model, allowing it to learn complex patterns.
#
# ### How Does a Neural Network Learn?
#
# Neural networks learn through a process called **training**. Here’s a simplified overview of how it works:
#
# 1. **Initialization**: The weights and biases are initialized, often randomly.
#
# 2. **Forward Pass**: The input data is fed into the network, and it passes through the layers. Each neuron processes the input, applies the weights and biases, and uses the activation function to produce an output.
#
# 3. **Loss Calculation**: The output of the network is compared to the actual target (the correct answer). A loss function calculates how far off the network's prediction is from the target.
#
# 4. **Backward Pass (Backpropagation)**: The network adjusts its weights and biases to minimize the loss. This is done using an optimization algorithm like gradient descent, which calculates the gradient (or slope) of the loss function and updates the weights in the opposite direction.
#
# 5. **Iteration**: Steps 2-4 are repeated for many iterations (or epochs) using the training data until the network learns to make accurate predictions.
#
# ### Applications of Neural Networks
#
# Neural networks are used in various applications, including:
#
# - **Image Recognition**: Identifying objects in images (e.g., facial recognition).
# - **Natural Language Processing**: Understanding and generating human language (e.g., chatbots, translation).
# - **Game Playing**: Learning to play games at a high level (e.g., AlphaGo).
# - **Medical Diagnosis**: Analyzing medical images or patient data to assist in diagnosis.
#
# ### Conclusion
#
# In summary, neural networks are powerful tools for pattern recognition and learning from data. They consist of layers of interconnected neurons that process information, and they learn through a process of adjusting weights and biases based on the errors they make. With their ability to model complex relationships, neural networks have become a cornerstone of modern artificial intelligence.
# ============================================================
#
#
# 💡 Notice: The optimized prompt produces similar quality output with 85% fewer tokens!

# %% [markdown]
# ### Example 2: Systematic Token Reduction Strategies
#
# Here are specific techniques to reduce token usage while maintaining clarity.

# %%
# Strategy 1: Remove filler words
before_1 = "Could you please help me understand how AI works?"
after_1 = "Explain how AI works."

# Strategy 2: Use abbreviations
before_2 = "Explain artificial intelligence and machine learning"
after_2 = "Explain AI and ML"

# Strategy 3: Use imperatives instead of questions
before_3 = "Can you tell me what are the benefits of cloud computing?"
after_3 = "List cloud computing benefits."

# Strategy 4: Remove redundancy
before_4 = "Please provide a detailed and comprehensive explanation of neural networks"
after_4 = "Explain neural networks comprehensively."

strategies = [
    ("Remove filler words", before_1, after_1),
    ("Use abbreviations", before_2, after_2),
    ("Use imperatives", before_3, after_3),
    ("Remove redundancy", before_4, after_4)
]

print("📋 Token Optimization Strategies:\n")
total_saved = 0

for strategy, before, after in strategies:
    before_tokens = count_tokens_approx(before)
    after_tokens = count_tokens_approx(after)
    saved = before_tokens - after_tokens
    total_saved += saved
    
    print(f"\n{strategy}:")
    print(f"  Before: \"{before}\" ({before_tokens} tokens)")
    print(f"  After:  \"{after}\" ({after_tokens} tokens)")
    print(f"  💰 Saved: {saved} tokens ({(saved/before_tokens*100):.0f}% reduction)")

print(f"\n{'='*80}")
print(f"📊 Total tokens saved across examples: {total_saved}")
print("\n💡 Apply these strategies consistently to reduce costs significantly!")
# Out:
# 📋 Token Optimization Strategies:
#
#
# Remove filler words:
#   Before: "Could you please help me understand how AI works?" (12 tokens)
#   After:  "Explain how AI works." (5 tokens)
#   💰 Saved: 7 tokens (58% reduction)
#
# Use abbreviations:
#   Before: "Explain artificial intelligence and machine learning" (13 tokens)
#   After:  "Explain AI and ML" (4 tokens)
#   💰 Saved: 9 tokens (69% reduction)
#
# Use imperatives:
#   Before: "Can you tell me what are the benefits of cloud computing?" (14 tokens)
#   After:  "List cloud computing benefits." (7 tokens)
#   💰 Saved: 7 tokens (50% reduction)
#
# Remove redundancy:
#   Before: "Please provide a detailed and comprehensive explanation of neural networks" (18 tokens)
#   After:  "Explain neural networks comprehensively." (10 tokens)
#   💰 Saved: 8 tokens (44% reduction)
#
# ================================================================================
# 📊 Total tokens saved across examples: 31
#
# 💡 Apply these strategies consistently to reduce costs significantly!

# %% [markdown]
# ### Example 3: Calculate Cost Savings
#
# Let's calculate the actual cost difference using OpenAI's pricing (as of 2024).

# %%
# OpenAI GPT-4o-mini pricing (example - check current pricing)
INPUT_COST_PER_1K = 0.00015  # $0.15 per 1M tokens
OUTPUT_COST_PER_1K = 0.0006   # $0.60 per 1M tokens

def calculate_cost(input_tokens, output_tokens):
    """Calculate cost based on token usage"""
    input_cost = (input_tokens / 1000) * INPUT_COST_PER_1K
    output_cost = (output_tokens / 1000) * OUTPUT_COST_PER_1K
    return input_cost + output_cost

# Example scenario: Running 1000 queries per day
queries_per_day = 1000
days_per_month = 30

# Scenario A: Verbose prompts
verbose_input_tokens = 150
verbose_output_tokens = 200

# Scenario B: Optimized prompts (50% reduction)
optimized_input_tokens = 75
optimized_output_tokens = 200  # Output stays same

# Calculate costs
verbose_cost_per_query = calculate_cost(verbose_input_tokens, verbose_output_tokens)
optimized_cost_per_query = calculate_cost(optimized_input_tokens, optimized_output_tokens)

verbose_monthly_cost = verbose_cost_per_query * queries_per_day * days_per_month
optimized_monthly_cost = optimized_cost_per_query * queries_per_day * days_per_month

savings_per_month = verbose_monthly_cost - optimized_monthly_cost
savings_per_year = savings_per_month * 12

print("💰 COST ANALYSIS")
print("="*80)
print(f"\nScenario: {queries_per_day} queries/day, {days_per_month} days/month")
print(f"\nVerbose Prompts:")
print(f"  - Cost per query: ${verbose_cost_per_query:.6f}")
print(f"  - Monthly cost: ${verbose_monthly_cost:.2f}")
print(f"\nOptimized Prompts:")
print(f"  - Cost per query: ${optimized_cost_per_query:.6f}")
print(f"  - Monthly cost: ${optimized_monthly_cost:.2f}")
print(f"\n{'='*80}")
print(f"💵 SAVINGS:")
print(f"  - Per month: ${savings_per_month:.2f}")
print(f"  - Per year: ${savings_per_year:.2f}")
print(f"  - Percentage saved: {(savings_per_month/verbose_monthly_cost*100):.1f}%")
print(f"\n{'='*80}")
print("💡 Token optimization isn't just about efficiency—it directly impacts your budget!")
# Out:
# 💰 COST ANALYSIS
# ================================================================================
#
# Scenario: 1000 queries/day, 30 days/month
#
# Verbose Prompts:
#   - Cost per query: $0.000142
#   - Monthly cost: $4.27
#
# Optimized Prompts:
#   - Cost per query: $0.000131
#   - Monthly cost: $3.94
#
# ================================================================================
# 💵 SAVINGS:
#   - Per month: $0.34
#   - Per year: $4.05
#   - Percentage saved: 7.9%
#
# ================================================================================
# 💡 Token optimization isn't just about efficiency—it directly impacts your budget!

# %% [markdown]
# ## 6. LLM as Judge (Brief Example)
#
# LLMs can evaluate the outputs from other LLMs. This technique is called "LLM as Judge" and is useful for comparing different prompts or responses.
#
# **Note:** This will be covered extensively in weeks 3, 4, and 6. Here's a quick preview.

# %%
# Generate multiple responses to evaluate
prompt = "Explain quantum computing in simple terms."

responses_to_judge = []
for i in range(3):
    response = call_openai(prompt, temperature=0.8)
    responses_to_judge.append(response)
    print(f"\nResponse {i+1}:")
    print(response)
    print("-"*80)
    time.sleep(0.5)
# Out:
# Response 1:
# Sure! Let’s break it down simply.
#
# ### What is Quantum Computing?
# Quantum computing is a new type of computing that uses the principles of quantum mechanics, which is the science that explains how very small particles, like atoms and photons, behave.
#
# ### How Does It Work?
# 1. **Bits vs. Qubits**:
#    - Traditional computers use **bits** as their basic unit of information, which can be either a 0 or a 1 (like a light switch that is either off or on).
#    - Quantum computers use **qubits** (quantum bits), which can be 0, 1, or both 0 and 1 at the same time, thanks to a property called **superposition**. Imagine it like a spinning coin that is simultaneously heads and tails until you stop it.
#
# 2. **Entanglement**:
#    - Qubits can also be **entangled**, which means the state of one qubit is directly related to the state of another, no matter how far apart they are. This allows quantum computers to perform complex calculations more efficiently than traditional computers.
#
# 3. **Parallel Processing**:
#    - Because of superposition and entanglement, quantum computers can process a massive amount of possibilities at the same time. This is like having many light switches that can be in numerous combinations all at once, rather than flipping them one at a time.
#
# ### Why is Quantum Computing Important?
# Quantum computing has the potential to solve certain problems much faster than classical computers. For example, it could help with:
# - **Cryptography**: Breaking complex codes that protect our data.
# - **Drug Discovery**: Simulating molecular interactions to find new medicines.
# - **Optimization Problems**: Finding the best solutions among a huge number of possibilities, like in logistics or finance.
#
# ### Summary:
# In simple terms, quantum computing is a powerful new technology that uses the strange rules of quantum mechanics to process information in ways that traditional computers can’t. It holds the promise of solving very complex problems much more efficiently than we've been able to do before.
# --------------------------------------------------------------------------------
#
# Response 2:
# Sure! Quantum computing is a type of computing that uses the principles of quantum mechanics, which is the science that explains how very tiny particles, like atoms and photons, behave.
#
# Here’s a simple breakdown:
#
# 1. **Bits vs. Qubits**: Traditional computers use bits as the smallest unit of information, which can be either a 0 or a 1. Quantum computers use qubits, which can be both 0 and 1 at the same time due to a property called superposition. This means a quantum computer can process a lot more information simultaneously compared to a traditional computer.
#
# 2. **Superposition**: Imagine a coin that can be heads, tails, or spinning in between. While it’s spinning, it represents superposition, capturing multiple possibilities at once. Similarly, qubits can represent different states simultaneously.
#
# 3. **Entanglement**: Qubits can also be entangled, which means the state of one qubit can depend on the state of another, no matter how far apart they are. This connection allows quantum computers to solve complex problems more efficiently than classical computers.
#
# 4. **Parallelism**: Because of superposition and entanglement, quantum computers can explore many solutions at the same time. This parallelism can potentially allow them to solve certain problems much faster than traditional computers.
#
# 5. **Applications**: Quantum computing has the potential to revolutionize fields like cryptography, drug discovery, optimization problems, and complex simulations in physics and chemistry.
#
# In summary, quantum computing harnesses the strange and powerful principles of quantum mechanics to process information in ways that traditional computers can't, enabling potentially faster and more efficient problem-solving.
# --------------------------------------------------------------------------------
#
# Response 3:
# Sure! Let's break it down into simple ideas:
#
# 1. **Bits vs. Qubits**: Traditional computers use bits as the smallest unit of data, which can be either a 0 or a 1. Quantum computers use qubits, which can be both 0 and 1 at the same time because of a property called superposition. This means that a qubit can represent more information than a regular bit.
#
# 2. **Superposition**: Imagine flipping a coin. While it's in the air, it's not just heads or tails, but a blend of both. Similarly, a qubit can exist in multiple states at once until we measure it, at which point it "collapses" to either 0 or 1.
#
# 3. **Entanglement**: This is a special connection between qubits. When qubits are entangled, the state of one qubit can depend on the state of another, no matter how far apart they are. This phenomenon allows quantum computers to process complex information in ways that classical computers cannot.
#
# 4. **Quantum Gates**: Just like classical computers use logic gates to perform operations on bits, quantum computers use quantum gates to manipulate qubits. These gates change the probabilities of a qubit being in a certain state when measured.
#
# 5. **Parallelism**: Because of superposition, a quantum computer can process many possibilities at once. This means they can solve certain problems much faster than traditional computers. For example, tasks like factoring large numbers or searching through large databases can be done more efficiently.
#
# 6. **Applications**: Quantum computing has the potential to revolutionize fields like cryptography, optimization, drug discovery, and artificial intelligence because they can handle complex calculations much quicker than classical computers.
#
# In summary, quantum computing is a new way of processing information that uses the unique properties of quantum mechanics to solve problems that are challenging for traditional computers.
# --------------------------------------------------------------------------------

# %%
# Use LLM as judge to evaluate and rank them
judge_prompt = f"""Evaluate these 3 explanations of quantum computing. Rate each on:
1. Clarity (1-10)
2. Accuracy (1-10)
3. Accessibility for beginners (1-10)

Response 1: {responses_to_judge[0]}

Response 2: {responses_to_judge[1]}

Response 3: {responses_to_judge[2]}

Provide scores for each response and recommend the best one. Format your response clearly."""

judgment = call_openai(judge_prompt, temperature=0)
display_response("LLM Judge Evaluation", judgment)

print("\n💡 Note: LLM as Judge will be covered in detail in weeks 3, 4, and 6!")
print("You'll learn advanced evaluation techniques and best practices.")
# Out:
# ============================================================
# 📝 LLM Judge Evaluation
# ============================================================
# Here are the evaluations for each response based on clarity, accuracy, and accessibility for beginners:
#
# ### Response 1:
# 1. **Clarity**: 9
#    - The explanation is well-structured and easy to follow, with clear examples and a logical flow.
#
# 2. **Accuracy**: 9
#    - The concepts of bits, qubits, superposition, and entanglement are accurately described, and the applications mentioned are relevant and correct.
#
# 3. **Accessibility for Beginners**: 9
#    - The use of analogies (like the spinning coin) makes it accessible for beginners, and the language is straightforward.
#
# ### Response 2:
# 1. **Clarity**: 8
#    - The explanation is clear, but it is slightly less structured than Response 1, which may make it a bit harder to follow for some beginners.
#
# 2. **Accuracy**: 9
#    - The information is accurate, covering the essential concepts of quantum computing effectively.
#
# 3. **Accessibility for Beginners**: 8
#    - While it is accessible, the lack of a more engaging analogy (like the spinning coin) may make it slightly less relatable for beginners compared to Response 1.
#
# ### Response 3:
# 1. **Clarity**: 7
#    - The explanation is clear but feels a bit more technical, especially with the introduction of quantum gates, which may confuse beginners.
#
# 2. **Accuracy**: 9
#    - The concepts are accurate, but the introduction of quantum gates may be too advanced for a beginner audience.
#
# 3. **Accessibility for Beginners**: 7
#    - While it provides good information, the mention of quantum gates and a more technical tone may make it less accessible for those new to the topic.
#
# ### Summary of Scores:
# - **Response 1**: Clarity: 9, Accuracy: 9, Accessibility: 9
# - **Response 2**: Clarity: 8, Accuracy: 9, Accessibility: 8
# - **Response 3**: Clarity: 7, Accuracy: 9, Accessibility: 7
#
# ### Recommendation:
# **Response 1** is the best explanation overall. It scores the highest in clarity, accuracy, and accessibility, making it the most suitable choice for beginners looking to understand quantum computing.
# ============================================================
#
#
# 💡 Note: LLM as Judge will be covered in detail in weeks 3, 4, and 6!
# You'll learn advanced evaluation techniques and best practices.

# %% [markdown]
# ## 7. Model Biases Demonstration
#
# AI models exhibit various cognitive biases that affect their outputs. Understanding these biases helps you design better prompts to mitigate them.

# %% [markdown]
# ### Recency Bias
#
# Models tend to remember what's at the **end** of the prompt and forget what's at the **beginning**.

# %%
# Test recency bias: important info at beginning vs end
prompt_important_first = """IMPORTANT: Your response must be exactly 2 sentences.

Explain the greenhouse effect and its impact on climate change."""

prompt_important_last = """Explain the greenhouse effect and its impact on climate change.

IMPORTANT: Your response must be exactly 2 sentences."""

print("Testing Recency Bias...\n")
print("="*80)

response_first = call_openai(prompt_important_first, temperature=0.7)
response_last = call_openai(prompt_important_last, temperature=0.7)

print("Important constraint at BEGINNING:")
print(response_first)
sentences_first = response_first.count('.') 
print(f"Sentences: {sentences_first}\n")

print("-"*80)
print("\nImportant constraint at END:")
print(response_last)
sentences_last = response_last.count('.')
print(f"Sentences: {sentences_last}\n")

print("="*80)
print("💡 The model often follows the constraint better when it's at the END!")
# Out:
# Testing Recency Bias...
#
# ================================================================================
# Important constraint at BEGINNING:
# The greenhouse effect occurs when certain gases in the Earth's atmosphere, such as carbon dioxide and methane, trap heat from the sun, preventing it from escaping back into space. This leads to an increase in global temperatures, contributing to climate change and resulting in severe weather patterns, rising sea levels, and disruptions to ecosystems.
# Sentences: 2
#
# --------------------------------------------------------------------------------
#
# Important constraint at END:
# The greenhouse effect occurs when certain gases in the Earth's atmosphere, such as carbon dioxide and methane, trap heat from the sun, leading to an increase in the planet's average temperature. This warming contributes to climate change by causing extreme weather events, rising sea levels, and disruptions to ecosystems.
# Sentences: 2
#
# ================================================================================
# 💡 The model often follows the constraint better when it's at the END!

# %% [markdown]
# ### Verbosity Bias
#
# Models tend to generate **long, elaborate responses** rather than brief, concise answers.

# %%
# Test verbosity bias
prompt_brief = "What is machine learning?"
prompt_explicit_brief = "What is machine learning? Answer in one sentence."

print("Testing Verbosity Bias...\n")
print("="*80)

response_natural = call_openai(prompt_brief, temperature=0.7)
response_constrained = call_openai(prompt_explicit_brief, temperature=0.7)

print("Without explicit brevity instruction:")
print(response_natural)
print(f"\nLength: {len(response_natural)} characters\n")

print("-"*80)
print("\nWith explicit brevity instruction:")
print(response_constrained)
print(f"\nLength: {len(response_constrained)} characters\n")

print("="*80)
print("💡 Without constraints, models tend toward verbose responses!")
# Out:
# Testing Verbosity Bias...
#
# ================================================================================
# Without explicit brevity instruction:
# Machine learning is a subset of artificial intelligence (AI) that involves the development of algorithms and statistical models that enable computers to perform tasks without explicit instructions. Instead of being programmed with specific rules, machine learning systems learn from data. Here are some key points about machine learning:
#
# 1. **Learning from Data**: Machine learning algorithms identify patterns, make decisions, or predictions based on the data they are trained on. The more data they are exposed to, the better they can learn and improve their performance.
#
# 2. **Types of Machine Learning**:
#    - **Supervised Learning**: The model is trained on labeled data, meaning that the input data is paired with the correct output. The goal is to learn a mapping from inputs to outputs (e.g., classification, regression).
#    - **Unsupervised Learning**: The model is trained on data without labeled responses. The goal is to identify underlying structures or patterns in the data (e.g., clustering, association).
#    - **Reinforcement Learning**: The model learns by interacting with an environment and receiving feedback in the form of rewards or penalties. It aims to learn a policy that maximizes cumulative rewards.
#
# 3. **Applications**: Machine learning is used in a wide range of applications, including:
#    - Image and speech recognition
#    - Natural language processing
#    - Recommendation systems
#    - Fraud detection
#    - Autonomous vehicles
#    - Healthcare diagnostics
#
# 4. **Techniques**: Common techniques in machine learning include:
#    - Decision trees
#    - Neural networks (including deep learning)
#    - Support vector machines
#    - k-nearest neighbors
#    - Ensemble methods (like random forests and boosting)
#
# 5. **Challenges**: Some challenges in machine learning include overfitting (when a model learns noise in the training data rather than the underlying pattern), bias in training data, and the need for large amounts of high-quality data.
#
# Overall, machine learning is a powerful tool that allows computers to learn from experience and improve their performance on specific tasks over time.
#
# Length: 2121 characters
#
# --------------------------------------------------------------------------------
#
# With explicit brevity instruction:
# Machine learning is a subset of artificial intelligence that focuses on the development of algorithms and statistical models that enable computers to learn from and make predictions or decisions based on data.
#
# Length: 209 characters
#
# ================================================================================
# 💡 Without constraints, models tend toward verbose responses!

# %% [markdown]
# ### List-Making Bias
#
# Models tend to format responses as **bullet points or numbered lists** rather than natural prose paragraphs.

# %%
# Test list-making bias
prompt_neutral = "What are the benefits of exercise?"
prompt_prose = "Write a paragraph about the benefits of exercise. Use flowing prose, not lists."

print("Testing List-Making Bias...\n")
print("="*80)

response_neutral = call_openai(prompt_neutral, temperature=0.7)
response_prose = call_openai(prompt_prose, temperature=0.7)

print("Without format specification:")
print(response_neutral)
print(f"\nContains bullet points or numbers: {('•' in response_neutral or '1.' in response_neutral or '-' in response_neutral)}")

print("\n" + "-"*80)
print("\nWith prose instruction:")
print(response_prose)
print(f"\nContains bullet points or numbers: {('•' in response_prose or '1.' in response_prose or '-' in response_prose[:50])}")

print("\n" + "="*80)
print("💡 Models default to lists—explicitly request prose format if needed!")
# Out:
# Testing List-Making Bias...
#
# ================================================================================
# Without format specification:
# Exercise offers a wide range of benefits that positively impact physical, mental, and emotional health. Here are some key benefits:
#
# ### Physical Health Benefits:
# 1. **Improved Cardiovascular Health**: Regular exercise strengthens the heart, improves circulation, and reduces the risk of heart disease and stroke.
# 2. **Weight Management**: Physical activity helps maintain a healthy weight by burning calories and increasing metabolism.
# 3. **Enhanced Muscle and Bone Strength**: Weight-bearing and resistance exercises increase muscle strength and bone density, which can help prevent osteoporosis.
# 4. **Improved Flexibility and Balance**: Activities like yoga and stretching improve flexibility and balance, reducing the risk of falls, especially in older adults.
# 5. **Boosted Immune System**: Moderate, regular exercise can enhance immune function and reduce the risk of chronic diseases.
# 6. **Better Sleep**: Regular physical activity can lead to improved sleep quality and duration.
#
# ### Mental Health Benefits:
# 1. **Reduced Stress and Anxiety**: Exercise can lower levels of stress hormones and trigger the release of endorphins, leading to improved mood and reduced anxiety.
# 2. **Enhanced Mood**: Physical activity stimulates the production of neurotransmitters like serotonin and dopamine, which can alleviate feelings of depression.
# 3. **Improved Cognitive Function**: Regular exercise is associated with better memory, attention, and overall cognitive performance.
# 4. **Increased Confidence and Self-Esteem**: Achieving fitness goals can boost self-esteem and body image.
#
# ### Emotional Well-Being:
# 1. **Social Interaction**: Group exercises and team sports provide opportunities for socializing, which can enhance emotional well-being.
# 2. **Mindfulness and Relaxation**: Activities like yoga and tai chi promote mindfulness and relaxation, helping to reduce mental fatigue and improve focus.
# 3. **Sense of Accomplishment**: Setting and achieving fitness goals can provide a sense of accomplishment and purpose.
#
# ### Longevity and Quality of Life:
# 1. **Increased Longevity**: Regular physical activity is associated with a longer lifespan and a lower risk of chronic diseases.
# 2. **Enhanced Quality of Life**: Those who exercise regularly often report a higher quality of life, with more energy and better overall health.
#
# ### Other Benefits:
# 1. **Improved Digestive Health**: Physical activity can help regulate digestion and prevent constipation.
# 2. **Better Skin Health**: Exercise improves blood circulation and can contribute to healthier skin.
# 3. **Enhanced Creativity**: Physical activity can stimulate creativity and improve problem-solving skills.
#
# Incorporating regular exercise into your routine can lead to significant improvements in overall health and well-being. It's important to choose activities you enjoy to maintain a consistent exercise routine.
#
# Contains bullet points or numbers: True
#
# --------------------------------------------------------------------------------
#
# With prose instruction:
# Exercise serves as a cornerstone of a healthy lifestyle, offering a myriad of benefits that extend far beyond the physical realm. Engaging in regular physical activity enhances cardiovascular health, strengthens muscles, and boosts endurance, fostering a body that feels vibrant and alive. Beyond the tangible improvements in strength and flexibility, exercise also plays a vital role in mental well-being, releasing endorphins that elevate mood and reduce stress, creating a natural antidote to the pressures of daily life. Furthermore, the discipline of maintaining a fitness routine instills a sense of accomplishment and purpose, while social activities, such as group classes or team sports, cultivate connections and camaraderie among individuals. Ultimately, the rhythm of movement not only invigorates the body but also nourishes the spirit, contributing to a holistic sense of health and vitality.
#
# Contains bullet points or numbers: False
#
# ================================================================================
# 💡 Models default to lists—explicitly request prose format if needed!

# %% [markdown]
# ## 8. Summary & Best Practices
#
# Congratulations! You've explored advanced prompt engineering techniques. Let's recap the key takeaways.

# %% [markdown]
# ### Key Takeaways
#
# **1. Core Techniques:**
# - Zero-shot: Clear descriptions without examples (most common)
# - One/Few-shot: Provide examples to guide format and style
# - Role prompting: Define assistant in third person for better results
# - Emotional prompting: Use emotion to influence tone
# - Chain-of-thought: Request step-by-step reasoning for complex tasks
#
# **2. Non-Deterministic Nature:**
# - LLM outputs vary between runs with same parameters
# - Use temperature=0 for consistency
# - Use seed parameter for reproducibility
# - Test prompts multiple times before deployment
#
# **3. Automatic Prompt Generation:**
# - Use AI to improve your prompts (meta-prompting)
# - Generate multiple variations automatically
# - Implement iterative refinement loops
# - Save time and discover better approaches
#
# **4. Token Optimization:**
# - Remove filler words and redundancy
# - Use abbreviations and imperatives
# - Token reduction = cost reduction
# - Maintain quality while minimizing tokens
#
# **5. Model Biases:**
# - Recency bias: Put important info at the end
# - Verbosity bias: Explicitly request brevity
# - List-making bias: Request prose format when needed
# - Design prompts to mitigate known biases
#
# **6. LLM as Judge:**
# - Use LLMs to evaluate other LLM outputs
# - Compare prompt variations objectively
# - More advanced techniques coming in weeks 3, 4, and 6

# %% [markdown]
# ### The Prompt Engineering Workflow
#
# Remember: Prompt engineering is an **empirical science**.
#
# ```
# 1. CREATE → 2. TEST → 3. ITERATE
#      ↑                       ↓
#      └───────────────────────┘
# ```
#
# **Create:** Write your initial prompt based on best practices
#
# **Test:** Run it multiple times with your actual use case
#
# **Iterate:** Refine based on results, biases, and failures
#
# **Repeat:** Continue until you achieve consistent, quality outputs

# %% [markdown]
# ### Building Your Prompt Toolkit
#
# **Save successful prompts** as templates or presets:
# - Data extraction prompts
# - Classification prompts
# - Creative writing prompts
# - Analysis and summarization prompts
#
# **Create templates** for common tasks:
# - Include placeholders for variable content
# - Document which parameters work best
# - Note any special considerations or biases
#
# **Version control** your prompts:
# - Track iterations and improvements
# - Document what works and what doesn't
# - Share learnings with your team

# %% [markdown]
# ### Quick Reference: Common Problems & Solutions
#
# | Problem | Solution |
# |---------|----------|
# | **Hallucination** | Lower temperature, add examples |
# | **Off-topic** | Stronger system message, lower top-p |
# | **Too verbose** | Set max_tokens limit, use stop sequences |
# | **Repetitive** | Increase repetition penalties |
# | **Inconsistent** | Set temperature=0, use seed value |
# | **Wrong format** | Enable JSON mode, provide clear format instructions |
# | **Ignoring instructions** | Move key instructions to end (recency bias) |
# | **Too expensive** | Optimize tokens, use cheaper models where appropriate |

# %% [markdown]
# ### Next Steps
#
# Now that you understand advanced prompt engineering:
#
# 1. **Practice** with the techniques in this notebook
# 2. **Apply** these strategies to your own projects
# 3. **Experiment** with different combinations
# 4. **Build** your own prompt library
# 5. **Look forward** to RAG and ReAct prompting in Week 3!
#
# ### Additional Resources
#
# - OpenAI Prompt Engineering Guide: https://platform.openai.com/docs/guides/prompt-engineering
# - Prompt Engineering Papers: https://github.com/dair-ai/Prompt-Engineering-Guide
# - Community Prompts: https://prompts.chat
#
# ---
#
# **Happy Prompting! 🚀**
